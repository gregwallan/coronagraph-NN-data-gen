# %%
# %matplotlib notebook
import numpy as np
import poppy
import matplotlib.pyplot as plt
import astropy.units as u
from generate_data_parallel import generate_wfe_array_uniform_overall

# %%
Nex = int(1e5)
overall_bound = 948e-9

# %%
wfe_array = generate_wfe_array_uniform_overall(overall_bound,Nex)

# %%
M = wfe_array.shape[0]
plt.figure()
for i in range(M):
    #plt.figure()
    plt.hist(wfe_array[i,:],bins=120,histtype='step')
# Out:
# <img src="data:image/png;base64,..." width="640">
